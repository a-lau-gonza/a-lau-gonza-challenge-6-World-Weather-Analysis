# %%
# Import dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import gmaps
import requests
import random
from citipy import citipy
from config import weather_api_key
from config import g_key
from datetime import datetime
from scipy.stats import linregress

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 767

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        try:
            city_rain_inches = city_weather["rain"]["1h"]
        except KeyError:
            city_rain_inches = 0
        try:
            city_snow_inches = city_weather["snow"]["1h"]
        except KeyError:
            city_snow_inches = 0
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description,
                          "Rain (inches)": city_rain_inches,
                          "Snow (inches)": city_snow_inches,
                          })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | kapaa
# Processing Record 2 of Set 1 | hede
# Processing Record 3 of Set 1 | bengkulu
# Processing Record 4 of Set 1 | sola
# Processing Record 5 of Set 1 | muskegon
# Processing Record 6 of Set 1 | atuona
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | grindavik
# Processing Record 9 of Set 1 | toamasina
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | mahebourg
# Processing Record 12 of Set 1 | nome
# Processing Record 13 of Set 1 | chokurdakh
# Processing Record 14 of Set 1 | hobart
# Processing Record 15 of Set 1 | vaini
# Processing Record 16 of Set 1 | cape town
# Processing Record 17 of Set 1 | kodiak
# Processing Record 18 of Set 1 | lebu
# Processing Record 19 of Set 1 | leningradskiy
# Processing Record 20 of Set 1 | kavieng
# Processing Record 21 of Set 1 | ostrovnoy
# Processing Record 22 of Set 1 | jiddah
# City not found. Skipping...
# Processing Record 23 of Set 1 | jamestown
# Processing Record 24 of Set 1 | parabel
# Processing Record 25 of Set 1 | khani
# Processing Record 26 of Set 1 | lincoln
# Processing Record 27 of Set 1 | butaritari
# Processing Record 28 of Set 1 | mulege
# Processing Record 29 of Set 1 | dikson
# Processing Record 30 of Set 1 | karibib
# Processing Record 31 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 1 | shangzhi
# Processing Record 33 of Set 1 | hakui
# Processing Record 34 of Set 1 | basco
# Processing Record 35 of Set 1 | pathalgaon
# Processing Record 36 of Set 1 | vila velha
# Processing Record 37 of Set 1 | fort saint james
# Processing Record 38 of Set 1 | hilo
# Processing Record 39 of Set 1 | palaikastron
# Processing Record 40 of Set 1 | bredasdorp
# Processing Record 41 of Set 1 | aklavik
# Processing Record 42 of Set 1 | ribeira grande
# Processing Record 43 of Set 1 | port alfred
# Processing Record 44 of Set 1 | bethel
# Processing Record 45 of Set 1 | haradok
# Processing Record 46 of Set 1 | lompoc
# Processing Record 47 of Set 1 | souillac
# Processing Record 48 of Set 1 | bonavista
# Processing Record 49 of Set 1 | buncrana
# Processing Record 50 of Set 1 | puerto ayora
# Processing Record 1 of Set 2 | san patricio
# Processing Record 2 of Set 2 | mar del plata
# Processing Record 3 of Set 2 | tiksi
# Processing Record 4 of Set 2 | tuktoyaktuk
# Processing Record 5 of Set 2 | achutupo
# Processing Record 6 of Set 2 | srednekolymsk
# Processing Record 7 of Set 2 | albany
# Processing Record 8 of Set 2 | rikitea
# Processing Record 9 of Set 2 | bluff
# Processing Record 10 of Set 2 | bitkine
# Processing Record 11 of Set 2 | bagotville
# Processing Record 12 of Set 2 | palmas de monte alto
# Processing Record 13 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 14 of Set 2 | port hardy
# Processing Record 15 of Set 2 | paamiut
# Processing Record 16 of Set 2 | upernavik
# Processing Record 17 of Set 2 | milford
# Processing Record 18 of Set 2 | ilulissat
# Processing Record 19 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 20 of Set 2 | sonoita
# Processing Record 21 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 2 | pavlohrad
# Processing Record 23 of Set 2 | wahpeton
# Processing Record 24 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 25 of Set 2 | pizhanka
# Processing Record 26 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 27 of Set 2 | huejuquilla el alto
# Processing Record 28 of Set 2 | ndele
# Processing Record 29 of Set 2 | road town
# Processing Record 30 of Set 2 | yellowknife
# Processing Record 31 of Set 2 | lorengau
# Processing Record 32 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 33 of Set 2 | asau
# Processing Record 34 of Set 2 | kununurra
# Processing Record 35 of Set 2 | barrow
# Processing Record 36 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 37 of Set 2 | broken hill
# Processing Record 38 of Set 2 | faanui
# Processing Record 39 of Set 2 | belyy yar
# Processing Record 40 of Set 2 | busselton
# Processing Record 41 of Set 2 | jambi
# Processing Record 42 of Set 2 | tasiilaq
# Processing Record 43 of Set 2 | caloundra
# Processing Record 44 of Set 2 | sayat
# Processing Record 45 of Set 2 | provideniya
# Processing Record 46 of Set 2 | nuevo ideal
# Processing Record 47 of Set 2 | port macquarie
# Processing Record 48 of Set 2 | chuy
# Processing Record 49 of Set 2 | deputatskiy
# Processing Record 50 of Set 2 | killybegs
# Processing Record 1 of Set 3 | kemijarvi
# Processing Record 2 of Set 3 | moses lake
# Processing Record 3 of Set 3 | maniitsoq
# Processing Record 4 of Set 3 | vila franca do campo
# Processing Record 5 of Set 3 | waingapu
# Processing Record 6 of Set 3 | miramar
# Processing Record 7 of Set 3 | santa vitoria do palmar
# Processing Record 8 of Set 3 | karratha
# Processing Record 9 of Set 3 | mezen
# Processing Record 10 of Set 3 | kadykchan
# City not found. Skipping...
# Processing Record 11 of Set 3 | georgetown
# Processing Record 12 of Set 3 | porto novo
# Processing Record 13 of Set 3 | smithers
# Processing Record 14 of Set 3 | auki
# Processing Record 15 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 16 of Set 3 | mehamn
# Processing Record 17 of Set 3 | cherskiy
# Processing Record 18 of Set 3 | vanderhoof
# Processing Record 19 of Set 3 | bambous virieux
# Processing Record 20 of Set 3 | kaitangata
# Processing Record 21 of Set 3 | castro
# Processing Record 22 of Set 3 | hermanus
# Processing Record 23 of Set 3 | tete
# Processing Record 24 of Set 3 | hofn
# Processing Record 25 of Set 3 | yanam
# Processing Record 26 of Set 3 | dalvik
# Processing Record 27 of Set 3 | doha
# Processing Record 28 of Set 3 | guerrero negro
# Processing Record 29 of Set 3 | winslow
# Processing Record 30 of Set 3 | ancud
# Processing Record 31 of Set 3 | new norfolk
# Processing Record 32 of Set 3 | kavaratti
# Processing Record 33 of Set 3 | desna
# Processing Record 34 of Set 3 | neiafu
# Processing Record 35 of Set 3 | arraial do cabo
# Processing Record 36 of Set 3 | hithadhoo
# Processing Record 37 of Set 3 | nyurba
# Processing Record 38 of Set 3 | torbay
# Processing Record 39 of Set 3 | lomovka
# Processing Record 40 of Set 3 | east london
# Processing Record 41 of Set 3 | qaanaaq
# Processing Record 42 of Set 3 | bathsheba
# Processing Record 43 of Set 3 | tuatapere
# Processing Record 44 of Set 3 | santiago
# Processing Record 45 of Set 3 | sulangan
# Processing Record 46 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 47 of Set 3 | saskylakh
# Processing Record 48 of Set 3 | buraydah
# Processing Record 49 of Set 3 | metro
# Processing Record 50 of Set 3 | ushuaia
# Processing Record 1 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 2 of Set 4 | kloulklubed
# Processing Record 3 of Set 4 | gafanha da encarnacao
# Processing Record 4 of Set 4 | dongsheng
# Processing Record 5 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 6 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 4 | namibe
# Processing Record 8 of Set 4 | fukue
# Processing Record 9 of Set 4 | isangel
# Processing Record 10 of Set 4 | geraldton
# Processing Record 11 of Set 4 | beira
# Processing Record 12 of Set 4 | thompson
# Processing Record 13 of Set 4 | manono
# Processing Record 14 of Set 4 | pevek
# Processing Record 15 of Set 4 | cabo san lucas
# Processing Record 16 of Set 4 | magadan
# Processing Record 17 of Set 4 | santa cruz
# Processing Record 18 of Set 4 | tabarqah
# City not found. Skipping...
# Processing Record 19 of Set 4 | yeniseysk
# Processing Record 20 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 21 of Set 4 | kulu
# Processing Record 22 of Set 4 | cidreira
# Processing Record 23 of Set 4 | saldanha
# Processing Record 24 of Set 4 | brae
# Processing Record 25 of Set 4 | roald
# Processing Record 26 of Set 4 | anahuac
# Processing Record 27 of Set 4 | coquimbo
# Processing Record 28 of Set 4 | micheweni
# Processing Record 29 of Set 4 | ust-kuyga
# Processing Record 30 of Set 4 | ginir
# Processing Record 31 of Set 4 | lata
# Processing Record 32 of Set 4 | pierre
# Processing Record 33 of Set 4 | ponta delgada
# Processing Record 34 of Set 4 | hirado
# Processing Record 35 of Set 4 | yarada
# Processing Record 36 of Set 4 | kahului
# Processing Record 37 of Set 4 | sibolga
# Processing Record 38 of Set 4 | grand-lahou
# Processing Record 39 of Set 4 | port-cartier
# Processing Record 40 of Set 4 | sopelana
# Processing Record 41 of Set 4 | weatherford
# Processing Record 42 of Set 4 | ponta do sol
# Processing Record 43 of Set 4 | praia
# Processing Record 44 of Set 4 | mullaitivu
# City not found. Skipping...
# Processing Record 45 of Set 4 | cadillac
# Processing Record 46 of Set 4 | barmer
# Processing Record 47 of Set 4 | college
# Processing Record 48 of Set 4 | yazykovo
# Processing Record 49 of Set 4 | cayenne
# Processing Record 50 of Set 4 | talnakh
# Processing Record 1 of Set 5 | tabou
# Processing Record 2 of Set 5 | pangnirtung
# Processing Record 3 of Set 5 | nouadhibou
# Processing Record 4 of Set 5 | avarua
# Processing Record 5 of Set 5 | khorramshahr
# Processing Record 6 of Set 5 | nagua
# Processing Record 7 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 5 | shihezi
# Processing Record 9 of Set 5 | baruun-urt
# Processing Record 10 of Set 5 | iqaluit
# Processing Record 11 of Set 5 | dunedin
# Processing Record 12 of Set 5 | alofi
# Processing Record 13 of Set 5 | xinzhi
# Processing Record 14 of Set 5 | port hedland
# Processing Record 15 of Set 5 | rypefjord
# Processing Record 16 of Set 5 | olafsvik
# Processing Record 17 of Set 5 | praia da vitoria
# Processing Record 18 of Set 5 | hualmay
# Processing Record 19 of Set 5 | vaitape
# Processing Record 20 of Set 5 | fort nelson
# Processing Record 21 of Set 5 | goderich
# Processing Record 22 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 5 | novyy urengoy
# Processing Record 24 of Set 5 | yatou
# Processing Record 25 of Set 5 | port hueneme
# Processing Record 26 of Set 5 | bon air
# Processing Record 27 of Set 5 | scottsburgh
# City not found. Skipping...
# Processing Record 28 of Set 5 | flin flon
# Processing Record 29 of Set 5 | lucera
# Processing Record 30 of Set 5 | chegdomyn
# Processing Record 31 of Set 5 | abu kamal
# Processing Record 32 of Set 5 | mataiea
# City not found. Skipping...
# Processing Record 33 of Set 5 | barawe
# City not found. Skipping...
# Processing Record 34 of Set 5 | lumby
# Processing Record 35 of Set 5 | novolvovsk
# City not found. Skipping...
# Processing Record 36 of Set 5 | portland
# Processing Record 37 of Set 5 | yulara
# Processing Record 38 of Set 5 | batemans bay
# Processing Record 39 of Set 5 | narsaq
# Processing Record 40 of Set 5 | yarim
# Processing Record 41 of Set 5 | mawlaik
# Processing Record 42 of Set 5 | cheuskiny
# City not found. Skipping...
# Processing Record 43 of Set 5 | arlit
# Processing Record 44 of Set 5 | abnub
# Processing Record 45 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 46 of Set 5 | muravlenko
# Processing Record 47 of Set 5 | erdenet
# Processing Record 48 of Set 5 | yunjinghong
# City not found. Skipping...
# Processing Record 49 of Set 5 | pokhara
# Processing Record 50 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 1 of Set 6 | corner brook
# Processing Record 2 of Set 6 | saint-philippe
# Processing Record 3 of Set 6 | zhanaozen
# Processing Record 4 of Set 6 | yichun
# Processing Record 5 of Set 6 | viedma
# Processing Record 6 of Set 6 | srandakan
# Processing Record 7 of Set 6 | te anau
# Processing Record 8 of Set 6 | severo-kurilsk
# Processing Record 9 of Set 6 | villeta
# Processing Record 10 of Set 6 | nemuro
# Processing Record 11 of Set 6 | mountain home
# Processing Record 12 of Set 6 | nikolskoye
# Processing Record 13 of Set 6 | ridgecrest
# Processing Record 14 of Set 6 | shangrao
# Processing Record 15 of Set 6 | general pico
# Processing Record 16 of Set 6 | vao
# Processing Record 17 of Set 6 | gat
# Processing Record 18 of Set 6 | andevoranto
# City not found. Skipping...
# Processing Record 19 of Set 6 | alta floresta
# Processing Record 20 of Set 6 | mega
# Processing Record 21 of Set 6 | villa alemana
# Processing Record 22 of Set 6 | big spring
# Processing Record 23 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 24 of Set 6 | kenai
# Processing Record 25 of Set 6 | syracuse
# Processing Record 26 of Set 6 | fairbanks
# Processing Record 27 of Set 6 | carupano
# Processing Record 28 of Set 6 | loralai
# Processing Record 29 of Set 6 | kodinsk
# Processing Record 30 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 31 of Set 6 | sitka
# Processing Record 32 of Set 6 | homer
# Processing Record 33 of Set 6 | tabukiniberu
# City not found. Skipping...
# Processing Record 34 of Set 6 | hamilton
# Processing Record 35 of Set 6 | khatanga
# Processing Record 36 of Set 6 | esperance
# Processing Record 37 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 38 of Set 6 | crato
# Processing Record 39 of Set 6 | mataram
# Processing Record 40 of Set 6 | wattegama
# Processing Record 41 of Set 6 | marawi
# Processing Record 42 of Set 6 | talcahuano
# Processing Record 43 of Set 6 | mbini
# Processing Record 44 of Set 6 | binahaan
# Processing Record 45 of Set 6 | vardo
# Processing Record 46 of Set 6 | mount gambier
# Processing Record 47 of Set 6 | irituia
# Processing Record 48 of Set 6 | bone
# Processing Record 49 of Set 6 | manoleasa
# Processing Record 50 of Set 6 | tigil
# Processing Record 1 of Set 7 | fethiye
# Processing Record 2 of Set 7 | ladario
# Processing Record 3 of Set 7 | teya
# Processing Record 4 of Set 7 | touros
# Processing Record 5 of Set 7 | kawalu
# Processing Record 6 of Set 7 | trairi
# Processing Record 7 of Set 7 | key largo
# Processing Record 8 of Set 7 | magdagachi
# Processing Record 9 of Set 7 | lavrentiya
# Processing Record 10 of Set 7 | hirara
# Processing Record 11 of Set 7 | simbahan
# Processing Record 12 of Set 7 | meulaboh
# Processing Record 13 of Set 7 | cape elizabeth
# City not found. Skipping...
# Processing Record 14 of Set 7 | gunjur
# Processing Record 15 of Set 7 | maragogi
# Processing Record 16 of Set 7 | tautira
# Processing Record 17 of Set 7 | cumaribo
# City not found. Skipping...
# Processing Record 18 of Set 7 | sisimiut
# Processing Record 19 of Set 7 | utiroa
# City not found. Skipping...
# Processing Record 20 of Set 7 | tolaga bay
# Processing Record 21 of Set 7 | irece
# Processing Record 22 of Set 7 | kushmurun
# Processing Record 23 of Set 7 | cowra
# Processing Record 24 of Set 7 | ondjiva
# Processing Record 25 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 26 of Set 7 | egvekinot
# Processing Record 27 of Set 7 | mantua
# Processing Record 28 of Set 7 | luderitz
# Processing Record 29 of Set 7 | vulcanesti
# Processing Record 30 of Set 7 | xichang
# Processing Record 31 of Set 7 | oksfjord
# Processing Record 32 of Set 7 | thessalon
# Processing Record 33 of Set 7 | yerbogachen
# Processing Record 34 of Set 7 | dinar
# Processing Record 35 of Set 7 | batouri
# Processing Record 36 of Set 7 | vanimo
# Processing Record 37 of Set 7 | tromso
# Processing Record 38 of Set 7 | roros
# Processing Record 39 of Set 7 | makrana
# Processing Record 40 of Set 7 | sinnamary
# Processing Record 41 of Set 7 | saveh
# Processing Record 42 of Set 7 | fortuna
# Processing Record 43 of Set 7 | zilair
# Processing Record 44 of Set 7 | nuuk
# Processing Record 45 of Set 7 | okhotsk
# Processing Record 46 of Set 7 | diapaga
# Processing Record 47 of Set 7 | sayan
# Processing Record 48 of Set 7 | ouadda
# Processing Record 49 of Set 7 | katha
# City not found. Skipping...
# Processing Record 50 of Set 7 | talara
# Processing Record 1 of Set 8 | san quintin
# Processing Record 2 of Set 8 | abalak
# Processing Record 3 of Set 8 | burnie
# Processing Record 4 of Set 8 | kropotkin
# Processing Record 5 of Set 8 | ukiah
# Processing Record 6 of Set 8 | tumbes
# Processing Record 7 of Set 8 | venice
# Processing Record 8 of Set 8 | biltine
# Processing Record 9 of Set 8 | saint george
# Processing Record 10 of Set 8 | chicama
# Processing Record 11 of Set 8 | arteaga
# Processing Record 12 of Set 8 | nishihara
# Processing Record 13 of Set 8 | northam
# Processing Record 14 of Set 8 | sao jose da coroa grande
# Processing Record 15 of Set 8 | fort frances
# Processing Record 16 of Set 8 | riyadh
# Processing Record 17 of Set 8 | port-gentil
# Processing Record 18 of Set 8 | saint-augustin
# Processing Record 19 of Set 8 | pentecoste
# Processing Record 20 of Set 8 | manaus
# Processing Record 21 of Set 8 | imbituba
# Processing Record 22 of Set 8 | rovaniemi
# Processing Record 23 of Set 8 | pionerskiy
# Processing Record 24 of Set 8 | ahipara
# Processing Record 25 of Set 8 | segou
# Processing Record 26 of Set 8 | lindi
# Processing Record 27 of Set 8 | lake havasu city
# Processing Record 28 of Set 8 | komsomolskiy
# Processing Record 29 of Set 8 | ust-shonosha
# Processing Record 30 of Set 8 | xiangxiang
# Processing Record 31 of Set 8 | khandyga
# Processing Record 32 of Set 8 | jinchang
# Processing Record 33 of Set 8 | kalinagar
# Processing Record 34 of Set 8 | ambilobe
# Processing Record 35 of Set 8 | port elizabeth
# Processing Record 36 of Set 8 | samarai
# Processing Record 37 of Set 8 | sibut
# Processing Record 38 of Set 8 | husavik
# Processing Record 39 of Set 8 | half moon bay
# Processing Record 40 of Set 8 | palauig
# Processing Record 41 of Set 8 | quatre cocos
# Processing Record 42 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 43 of Set 8 | kutum
# Processing Record 44 of Set 8 | dabrowa tarnowska
# Processing Record 45 of Set 8 | zhigansk
# Processing Record 46 of Set 8 | trinidad
# Processing Record 47 of Set 8 | waipawa
# Processing Record 48 of Set 8 | qorveh
# Processing Record 49 of Set 8 | loei
# Processing Record 50 of Set 8 | truth or consequences
# Processing Record 1 of Set 9 | shitanjing
# Processing Record 2 of Set 9 | izumo
# Processing Record 3 of Set 9 | gusinoye ozero
# Processing Record 4 of Set 9 | shache
# Processing Record 5 of Set 9 | fort-shevchenko
# Processing Record 6 of Set 9 | najran
# Processing Record 7 of Set 9 | airai
# Processing Record 8 of Set 9 | merauke
# Processing Record 9 of Set 9 | inhambane
# Processing Record 10 of Set 9 | balikpapan
# Processing Record 11 of Set 9 | aksu
# Processing Record 12 of Set 9 | buala
# Processing Record 13 of Set 9 | letka
# Processing Record 14 of Set 9 | farah
# Processing Record 15 of Set 9 | lakeside
# Processing Record 16 of Set 9 | carnarvon
# Processing Record 17 of Set 9 | moba
# Processing Record 18 of Set 9 | curup
# Processing Record 19 of Set 9 | victoria
# Processing Record 20 of Set 9 | galiwinku
# City not found. Skipping...
# Processing Record 21 of Set 9 | dingle
# Processing Record 22 of Set 9 | nalut
# Processing Record 23 of Set 9 | pervomayskoye
# Processing Record 24 of Set 9 | berlevag
# Processing Record 25 of Set 9 | nabire
# Processing Record 26 of Set 9 | blythe
# Processing Record 27 of Set 9 | mulheim
# Processing Record 28 of Set 9 | kaihua
# Processing Record 29 of Set 9 | kabanjahe
# Processing Record 30 of Set 9 | zyryanovsk
# Processing Record 31 of Set 9 | makakilo city
# Processing Record 32 of Set 9 | nyahururu
# Processing Record 33 of Set 9 | atambua
# Processing Record 34 of Set 9 | norman wells
# Processing Record 35 of Set 9 | machaneng
# Processing Record 36 of Set 9 | lerwick
# Processing Record 37 of Set 9 | grimmen
# Processing Record 38 of Set 9 | pisco
# Processing Record 39 of Set 9 | haines junction
# Processing Record 40 of Set 9 | aitape
# Processing Record 41 of Set 9 | pascagoula
# Processing Record 42 of Set 9 | rudbar
# Processing Record 43 of Set 9 | adrar
# Processing Record 44 of Set 9 | kruisfontein
# Processing Record 45 of Set 9 | kasongo-lunda
# Processing Record 46 of Set 9 | tazovskiy
# Processing Record 47 of Set 9 | olinda
# Processing Record 48 of Set 9 | artyk
# City not found. Skipping...
# Processing Record 49 of Set 9 | caravelas
# Processing Record 50 of Set 9 | poya
# Processing Record 1 of Set 10 | miami
# Processing Record 2 of Set 10 | bilma
# Processing Record 3 of Set 10 | azul
# Processing Record 4 of Set 10 | yithion
# City not found. Skipping...
# Processing Record 5 of Set 10 | north bend
# Processing Record 6 of Set 10 | beringovskiy
# Processing Record 7 of Set 10 | sorland
# Processing Record 8 of Set 10 | itarema
# Processing Record 9 of Set 10 | oyama
# Processing Record 10 of Set 10 | clyde river
# Processing Record 11 of Set 10 | parrita
# Processing Record 12 of Set 10 | boras
# Processing Record 13 of Set 10 | sampit
# Processing Record 14 of Set 10 | bloemhof
# Processing Record 15 of Set 10 | pontes e lacerda
# Processing Record 16 of Set 10 | oussouye
# Processing Record 17 of Set 10 | callaway
# Processing Record 18 of Set 10 | mailsi
# Processing Record 19 of Set 10 | klaksvik
# Processing Record 20 of Set 10 | strezhevoy
# Processing Record 21 of Set 10 | nanortalik
# Processing Record 22 of Set 10 | cloquet
# Processing Record 23 of Set 10 | hunza
# City not found. Skipping...
# Processing Record 24 of Set 10 | huarmey
# Processing Record 25 of Set 10 | korla
# Processing Record 26 of Set 10 | tatarsk
# Processing Record 27 of Set 10 | buin
# Processing Record 28 of Set 10 | mudyuga
# City not found. Skipping...
# Processing Record 29 of Set 10 | katobu
# Processing Record 30 of Set 10 | hue
# Processing Record 31 of Set 10 | chumikan
# Processing Record 32 of Set 10 | coari
# Processing Record 33 of Set 10 | sechura
# Processing Record 34 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 10 | saint-pierre
# Processing Record 36 of Set 10 | craig
# Processing Record 37 of Set 10 | grand gaube
# Processing Record 38 of Set 10 | belaya gora
# Processing Record 39 of Set 10 | taft
# Processing Record 40 of Set 10 | boende
# Processing Record 41 of Set 10 | pangai
# Processing Record 42 of Set 10 | vila
# Processing Record 43 of Set 10 | tres rios
# Processing Record 44 of Set 10 | turukhansk
# Processing Record 45 of Set 10 | dinsor
# City not found. Skipping...
# Processing Record 46 of Set 10 | san francisco del mar
# Processing Record 47 of Set 10 | lagoa
# Processing Record 48 of Set 10 | bandarbeyla
# Processing Record 49 of Set 10 | acapulco
# Processing Record 50 of Set 10 | bonthe
# Processing Record 1 of Set 11 | katsuura
# Processing Record 2 of Set 11 | tura
# Processing Record 3 of Set 11 | chute-aux-outardes
# Processing Record 4 of Set 11 | tocopilla
# Processing Record 5 of Set 11 | milingimbi
# City not found. Skipping...
# Processing Record 6 of Set 11 | romny
# Processing Record 7 of Set 11 | thenzawl
# Processing Record 8 of Set 11 | moose factory
# Processing Record 9 of Set 11 | manokwari
# Processing Record 10 of Set 11 | zlobin
# Processing Record 11 of Set 11 | kupang
# Processing Record 12 of Set 11 | marsh harbour
# Processing Record 13 of Set 11 | kayerkan
# Processing Record 14 of Set 11 | mitsamiouli
# Processing Record 15 of Set 11 | marsa matruh
# Processing Record 16 of Set 11 | jackson
# Processing Record 17 of Set 11 | los llanos de aridane
# Processing Record 18 of Set 11 | cabedelo
# Processing Record 19 of Set 11 | laguna
# Processing Record 20 of Set 11 | xuddur
# Processing Record 21 of Set 11 | port said
# Processing Record 22 of Set 11 | pulandian
# Processing Record 23 of Set 11 | akyab
# Processing Record 24 of Set 11 | margate
# Processing Record 25 of Set 11 | camacha
# Processing Record 26 of Set 11 | chitungwiza
# Processing Record 27 of Set 11 | mabaruma
# Processing Record 28 of Set 11 | badulla
# Processing Record 29 of Set 11 | pacific grove
# Processing Record 30 of Set 11 | mayskiy
# Processing Record 31 of Set 11 | taihe
# Processing Record 32 of Set 11 | sao joao da barra
# Processing Record 33 of Set 11 | shitkino
# Processing Record 34 of Set 11 | chalus
# Processing Record 35 of Set 11 | wanning
# Processing Record 36 of Set 11 | tierra colorada
# Processing Record 37 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 38 of Set 11 | pinawa
# Processing Record 39 of Set 11 | tuy hoa
# Processing Record 40 of Set 11 | masyaf
# Processing Record 41 of Set 11 | lodwar
# Processing Record 42 of Set 11 | keflavik
# Processing Record 43 of Set 11 | poltava
# Processing Record 44 of Set 11 | rio grande
# Processing Record 45 of Set 11 | mahenge
# Processing Record 46 of Set 11 | murchison
# Processing Record 47 of Set 11 | christchurch
# Processing Record 48 of Set 11 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 11 | tonj
# Processing Record 50 of Set 11 | ahuimanu
# Processing Record 1 of Set 12 | huron
# Processing Record 2 of Set 12 | locri
# Processing Record 3 of Set 12 | champerico
# Processing Record 4 of Set 12 | dukat
# Processing Record 5 of Set 12 | ciudad del maiz
# Processing Record 6 of Set 12 | hadejia
# Processing Record 7 of Set 12 | acari
# Processing Record 8 of Set 12 | zapolyarnyy
# Processing Record 9 of Set 12 | faya
# Processing Record 10 of Set 12 | cap malheureux
# Processing Record 11 of Set 12 | singaraja
# Processing Record 12 of Set 12 | formoso do araguaia
# City not found. Skipping...
# Processing Record 13 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 14 of Set 12 | libreville
# Processing Record 15 of Set 12 | kroya
# Processing Record 16 of Set 12 | vanavara
# Processing Record 17 of Set 12 | vostok
# Processing Record 18 of Set 12 | itaituba
# Processing Record 19 of Set 12 | yakima
# Processing Record 20 of Set 12 | wasilla
# Processing Record 21 of Set 12 | honningsvag
# Processing Record 22 of Set 12 | avera
# Processing Record 23 of Set 12 | comodoro rivadavia
# Processing Record 24 of Set 12 | snezhnogorsk
# Processing Record 25 of Set 12 | robinson
# Processing Record 26 of Set 12 | krasnovka
# Processing Record 27 of Set 12 | tema
# Processing Record 28 of Set 12 | blagoyevo
# Processing Record 29 of Set 12 | paragominas
# Processing Record 30 of Set 12 | rundu
# Processing Record 31 of Set 12 | opuwo
# Processing Record 32 of Set 12 | sigli
# Processing Record 33 of Set 12 | hami
# Processing Record 34 of Set 12 | takoradi
# Processing Record 35 of Set 12 | ganzhou
# Processing Record 36 of Set 12 | nagornyy
# Processing Record 37 of Set 12 | crab hill
# City not found. Skipping...
# Processing Record 38 of Set 12 | naze
# Processing Record 39 of Set 12 | taoudenni
# Processing Record 40 of Set 12 | peniche
# Processing Record 41 of Set 12 | abha
# Processing Record 42 of Set 12 | tonantins
# Processing Record 43 of Set 12 | ketchikan
# Processing Record 44 of Set 12 | sumbawa
# City not found. Skipping...
# Processing Record 45 of Set 12 | ituni
# City not found. Skipping...
# Processing Record 46 of Set 12 | curug
# Processing Record 47 of Set 12 | solnechnyy
# Processing Record 48 of Set 12 | tilichiki
# Processing Record 49 of Set 12 | campos altos
# Processing Record 50 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 1 of Set 13 | poum
# Processing Record 2 of Set 13 | padang
# Processing Record 3 of Set 13 | bolitoc
# Processing Record 4 of Set 13 | paradwip
# City not found. Skipping...
# Processing Record 5 of Set 13 | longyearbyen
# Processing Record 6 of Set 13 | pahrump
# Processing Record 7 of Set 13 | necochea
# Processing Record 8 of Set 13 | bara
# Processing Record 9 of Set 13 | qui nhon
# Processing Record 10 of Set 13 | smidovich
# Processing Record 11 of Set 13 | tidore
# City not found. Skipping...
# Processing Record 12 of Set 13 | rocha
# Processing Record 13 of Set 13 | polunochnoye
# Processing Record 14 of Set 13 | blyth
# Processing Record 15 of Set 13 | yangcun
# Processing Record 16 of Set 13 | moscow
# Processing Record 17 of Set 13 | chitral
# Processing Record 18 of Set 13 | alto piquiri
# Processing Record 19 of Set 13 | tomatlan
# Processing Record 20 of Set 13 | gisborne
# Processing Record 21 of Set 13 | burley
# Processing Record 22 of Set 13 | belle fourche
# Processing Record 23 of Set 13 | nosy varika
# Processing Record 24 of Set 13 | huilong
# Processing Record 25 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 26 of Set 13 | flinders
# Processing Record 27 of Set 13 | port lincoln
# Processing Record 28 of Set 13 | jablah
# Processing Record 29 of Set 13 | orahovac
# Processing Record 30 of Set 13 | malakal
# Processing Record 31 of Set 13 | coahuayana
# Processing Record 32 of Set 13 | saryshagan
# City not found. Skipping...
# Processing Record 33 of Set 13 | oktyabrskiy
# Processing Record 34 of Set 13 | alice springs
# Processing Record 35 of Set 13 | portarlington
# Processing Record 36 of Set 13 | coihaique
# Processing Record 37 of Set 13 | arrifes
# Processing Record 38 of Set 13 | jiuquan
# Processing Record 39 of Set 13 | tyumentsevo
# Processing Record 40 of Set 13 | navahrudak
# Processing Record 41 of Set 13 | binika
# Processing Record 42 of Set 13 | holme
# Processing Record 43 of Set 13 | poso
# Processing Record 44 of Set 13 | dakar
# Processing Record 45 of Set 13 | miracema do tocantins
# Processing Record 46 of Set 13 | roma
# Processing Record 47 of Set 13 | yeletskiy
# City not found. Skipping...
# Processing Record 48 of Set 13 | anito
# Processing Record 49 of Set 13 | luena
# Processing Record 50 of Set 13 | rawson
# Processing Record 1 of Set 14 | vera cruz
# Processing Record 2 of Set 14 | troy
# Processing Record 3 of Set 14 | sur
# Processing Record 4 of Set 14 | codrington
# Processing Record 5 of Set 14 | beberibe
# Processing Record 6 of Set 14 | eureka
# Processing Record 7 of Set 14 | batsfjord
# Processing Record 8 of Set 14 | muros
# Processing Record 9 of Set 14 | kisangani
# Processing Record 10 of Set 14 | the pas
# Processing Record 11 of Set 14 | khristoforovo
# City not found. Skipping...
# Processing Record 12 of Set 14 | sakakah
# Processing Record 13 of Set 14 | yurimaguas
# Processing Record 14 of Set 14 | urusha
# Processing Record 15 of Set 14 | lukovetskiy
# Processing Record 16 of Set 14 | mosquera
# Processing Record 17 of Set 14 | aporawan
# City not found. Skipping...
# Processing Record 18 of Set 14 | bam
# Processing Record 19 of Set 14 | nuoro
# Processing Record 20 of Set 14 | paita
# Processing Record 21 of Set 14 | cruzeiro
# Processing Record 22 of Set 14 | carnot
# Processing Record 23 of Set 14 | mazara del vallo
# Processing Record 24 of Set 14 | cockburn town
# Processing Record 25 of Set 14 | ouesso
# Processing Record 26 of Set 14 | tevaitoa
# Processing Record 27 of Set 14 | king city
# Processing Record 28 of Set 14 | batticaloa
# Processing Record 29 of Set 14 | ashtian
# Processing Record 30 of Set 14 | yumen
# Processing Record 31 of Set 14 | la carolina
# Processing Record 32 of Set 14 | ippy
# Processing Record 33 of Set 14 | chapadinha
# Processing Record 34 of Set 14 | kindu
# Processing Record 35 of Set 14 | kheda
# Processing Record 36 of Set 14 | el banco
# Processing Record 37 of Set 14 | florianopolis
# Processing Record 38 of Set 14 | halifax
# Processing Record 39 of Set 14 | lima
# Processing Record 40 of Set 14 | along
# Processing Record 41 of Set 14 | belmonte
# Processing Record 42 of Set 14 | den helder
# Processing Record 43 of Set 14 | pilar
# Processing Record 44 of Set 14 | plettenberg bay
# Processing Record 45 of Set 14 | kampene
# Processing Record 46 of Set 14 | kourou
# Processing Record 47 of Set 14 | moosomin
# Processing Record 48 of Set 14 | carmen
# Processing Record 49 of Set 14 | dire
# Processing Record 50 of Set 14 | carutapera
# Processing Record 1 of Set 15 | high level
# Processing Record 2 of Set 15 | pareora
# Processing Record 3 of Set 15 | dahanu
# Processing Record 4 of Set 15 | xihua
# Processing Record 5 of Set 15 | tiarei
# Processing Record 6 of Set 15 | mahibadhoo
# Processing Record 7 of Set 15 | qaqortoq
# Processing Record 8 of Set 15 | kitob
# Processing Record 9 of Set 15 | saint-georges
# Processing Record 10 of Set 15 | iranshahr
# Processing Record 11 of Set 15 | skovde
# City not found. Skipping...
# Processing Record 12 of Set 15 | otorohanga
# Processing Record 13 of Set 15 | wajir
# Processing Record 14 of Set 15 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 15 of Set 15 | mielec
# Processing Record 16 of Set 15 | eskasem
# City not found. Skipping...
# Processing Record 17 of Set 15 | kota kinabalu
# Processing Record 18 of Set 15 | nioro
# Processing Record 19 of Set 15 | kasulu
# Processing Record 20 of Set 15 | bontang
# Processing Record 21 of Set 15 | macenta
# Processing Record 22 of Set 15 | arman
# Processing Record 23 of Set 15 | carman
# Processing Record 24 of Set 15 | matagami
# Processing Record 25 of Set 15 | nenjiang
# Processing Record 26 of Set 15 | funadhoo
# Processing Record 27 of Set 15 | seoul
# Processing Record 28 of Set 15 | port blair
# Processing Record 29 of Set 15 | ulladulla
# Processing Record 30 of Set 15 | banda aceh
# Processing Record 31 of Set 15 | huallanca
# Processing Record 32 of Set 15 | richards bay
# Processing Record 33 of Set 15 | yenagoa
# Processing Record 34 of Set 15 | inverness
# Processing Record 35 of Set 15 | ust-nera
# Processing Record 36 of Set 15 | almaznyy
# Processing Record 37 of Set 15 | lokeren
# Processing Record 38 of Set 15 | mogadishu
# Processing Record 39 of Set 15 | tianpeng
# Processing Record 40 of Set 15 | payo
# Processing Record 41 of Set 15 | bisira
# Processing Record 42 of Set 15 | san jose
# Processing Record 43 of Set 15 | mwanza
# Processing Record 44 of Set 15 | peleduy
# Processing Record 45 of Set 15 | baie-comeau
# Processing Record 46 of Set 15 | kaeo
# Processing Record 47 of Set 15 | namatanai
# Processing Record 48 of Set 15 | constitucion
# Processing Record 49 of Set 15 | igarka
# Processing Record 50 of Set 15 | songjianghe
# Processing Record 1 of Set 16 | saint joseph
# Processing Record 2 of Set 16 | hailar
# Processing Record 3 of Set 16 | yakymivka
# Processing Record 4 of Set 16 | westport
# Processing Record 5 of Set 16 | bowen
# Processing Record 6 of Set 16 | san joaquin
# Processing Record 7 of Set 16 | sulya
# Processing Record 8 of Set 16 | rosita
# Processing Record 9 of Set 16 | maracacume
# Processing Record 10 of Set 16 | chapais
# Processing Record 11 of Set 16 | pemangkat
# Processing Record 12 of Set 16 | huambo
# Processing Record 13 of Set 16 | kalat
# Processing Record 14 of Set 16 | pitimbu
# Processing Record 15 of Set 16 | kamiiso
# Processing Record 16 of Set 16 | lasa
# Processing Record 17 of Set 16 | tobane
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
# challenge objective 
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Kapaa      US  22.0752 -159.3190     86.32        66           1
# 1        Hede      CN  33.7681  120.2517     77.95        87          67
# 2    Bengkulu      ID  -3.8004  102.2655     74.80        87          69
# 3        Sola      VU -13.8833  167.5500     75.87        88          90
# 4    Muskegon      US  43.3000  -86.1334     75.22        61          20
# ..        ...     ...      ...       ...       ...       ...         ...
# 698     Kalat      PK  29.0225   66.5916     66.97        62          37
# 699   Pitimbu      BR  -7.4706  -34.8086     73.99        78          40
# 700   Kamiiso      JP  41.8167  140.6500     66.58        77          75
# 701      Lasa      IT  46.6166   10.7002     68.88        83          10
# 702    Tobane      BW -21.9500   27.9000     51.10        86           0
#
#      Wind Speed Current Description  Rain (inches)  Snow (inches)
# 0          4.00           clear sky            0.0              0
# 1          6.08       broken clouds            0.0              0
# 2          4.27       broken clouds            0.0              0
# 3          9.22     overcast clouds            0.0              0
# 4          5.75          few clouds            0.0              0
# ..          ...                 ...            ...            ...
# 698        3.60    scattered clouds            0.0              0
# 699       14.20    scattered clouds            0.0              0
# 700       12.66       broken clouds            0.0              0
# 701        3.15           clear sky            0.0              0
# 702        6.64           clear sky            0.0              0
#
# [703 rows x 11 columns]

# %%
raining_cities = city_data_df.loc[city_data_df["Rain (inches)"] > 0]
raining_cities.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 8    Toamasina      MG -18.1667   49.3833     62.60        94          75
# 10   Mahebourg      MU -20.4081   57.7000     68.29        83          40
# 11        Nome      US  64.5011 -165.4064     50.07        82          90
# 19     Kavieng      PG  -2.5744  150.7967     83.64        74          83
# 23       Khani      GE  41.9563   42.9566     60.37        98          99
# 31       Basco      PH  20.4487  121.9702     84.15        78          77
# 61     Paamiut      GL  61.9940  -49.6678     46.11        99         100
# 62   Upernavik      GL  72.7868  -56.1549     42.78        95         100
# 70       Ndele      CF   8.4109   20.6473     70.00        93          98
# 103       Auki      SB  -8.7676  160.7034     84.47        68          84
#
#      Wind Speed   Current Description  Rain (inches)  Snow (inches)
# 8          5.75            light rain           0.32              0
# 10        10.36            light rain           0.36              0
# 11         8.05            light rain           0.68              0
# 19         8.88            light rain           0.96              0
# 23         1.23         moderate rain           2.37              0
# 31        12.33            light rain           0.87              0
# 61        22.82  heavy intensity rain           4.28              0
# 62         5.03            light rain           0.69              0
# 70         2.21            light rain           0.46              0
# 103        4.63         moderate rain           2.37              0

# %%
snowing_cities = city_data_df.loc[city_data_df["Snow (inches)"] > 0]
snowing_cities.head(10)
# Out:
# Empty DataFrame
# Columns: [City, Country, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Current Description, Rain (inches), Snow (inches)]
# Index: []

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
